# %%
def func_with_io():
    for i in range(int(1e5)):
        print('/', end='')

# %%
def func():
    for i in range(int(1e5)):
        pass

# %%
# %load_ext line_profiler

# %lprun -f func func()

# %%
# %lprun -f func_with_io func_with_io()
# Out:
# ...
# Timer unit: 1e-09 s
#
# Total time: 0.203106 s
# File: /var/folders/sy/3knjgqnn76l0fvddhk2jb6lm0000gn/T/ipykernel_49685/1919253013.py
# Function: func_with_io at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#      1                                           def func_with_io():
#      2    100000    8505000.0     85.0      4.2      for i in range(int(1e5)):
#      3    100000  194601000.0   1946.0     95.8          print('/', end='')

# %%
def func_file_io():
    fp = open('test.txt', 'w')
    x = 1
    fp.write(str(x))
    fp.close()

# %%
# %lprun -f func_file_io func_file_io()
# Out:
# Timer unit: 1e-09 s
#
# Total time: 0.000231 s
# File: /var/folders/sy/3knjgqnn76l0fvddhk2jb6lm0000gn/T/ipykernel_49685/3538929719.py
# Function: func_file_io at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#      1                                           def func_file_io():
#      2         1     129000.0 129000.0     55.8      fp = open('test.txt', 'w')
#      3         1          0.0      0.0      0.0      x = 1
#      4         1       1000.0   1000.0      0.4      fp.write(str(x))
#      5         1     101000.0 101000.0     43.7      fp.close()
